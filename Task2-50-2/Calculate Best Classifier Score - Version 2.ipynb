# %%
# Set constants
DATASET = "Task 2 (50% Noise)"
ALLOW_ONLY_HP_MATCHES = True
TRIALS_REQUIRED = 3
DIFFERENCE_THRESHS = [1.05, 1.1, 1.5, 3, 4.5]

# %%
# Load data
import pandas as pd

data = pd.read_csv("latent_trials.csv")
data.head()
# Out:
#                 Classifier     Based on AE  sigma  precision  recall  \
# 0  ReconstructionThreshold  20240209103156    0.8   0.517241  0.9375
# 1  ReconstructionThreshold  20240209103156    1.0   0.481481  0.8125
# 2  ReconstructionThreshold  20240209103156    1.2   0.416667  0.6250
# 3  ReconstructionThreshold  20240209103156    1.4   0.263158  0.3125
# 4  ReconstructionThreshold  20240209103156    1.6   0.176471  0.1875
#
#     f-score  max_iter  auc  n_estimators  max_depth  ...  gamma  kernel  \
# 0  0.666667       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 1  0.604651       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 2  0.500000       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 3  0.285714       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 4  0.181818       NaN  NaN           NaN        NaN  ...    NaN     NaN
#
#    probability  algorithm leaf_size n_neighbors sigma_base  sigma_mult  \
# 0          NaN        NaN       NaN         NaN        NaN         NaN
# 1          NaN        NaN       NaN         NaN        NaN         NaN
# 2          NaN        NaN       NaN         NaN        NaN         NaN
# 3          NaN        NaN       NaN         NaN        NaN         NaN
# 4          NaN        NaN       NaN         NaN        NaN         NaN
#
#    contamination  n_bins
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN
#
# [5 rows x 23 columns]

# %%
# Add processed classifer column
data["Processed Classifier"] = [classifier + "_%.2f" % sigma if classifier == "ReconstructionThreshold" else classifier for classifier, sigma in data[["Classifier", "sigma"]].values]
# data["Processed Classifier"] = data["Classifier"]
data = data.drop(columns=["Classifier"])

data["Dataset"] = [DATASET for _ in data.index]

# %%
# Add AE data

ae_data = pd.read_csv("ae_trials.csv", keep_default_na=False)
ae_data = ae_data[["name", "type", "input_size", "attempt", "leader" , "masking", "mask_size"]]
ae_data["Primary Model"] = ["%d" % float(leader) if leader else "%d" % float(base) for base, leader in ae_data[["name", "leader"]].values]
ae_data = ae_data.drop(columns=["leader"])

ae_data["type"] = [type + " (%.2f Masked)" % mask_size if mask else type for type, mask, mask_size in ae_data[["type", "masking", "mask_size"]].values]

ae_data.head()
# Out:
#              name            type  input_size  attempt  masking  mask_size  \
# 0  20240209103156  Adversarial AE        4096        0    False        0.5
# 1  20240209103238      Vanilla AE        4096        0    False        0.5
# 2  20240209103321  Adversarial AE        4096        1    False        0.5
# 3  20240209103401      Vanilla AE        4096        1    False        0.5
# 4  20240209103446  Adversarial AE        4096        2    False        0.5
#
#     Primary Model
# 0  20240209103156
# 1  20240209103156
# 2  20240209103156
# 3  20240209103156
# 4  20240209103156

# %%
# Convert AE data to dict and add to ll data

ae_data = {name: [name, ae_type, input_size, attempt, primary, masking, mask_size] for name, ae_type, input_size, attempt, masking, mask_size, primary in ae_data.values}
data = data[[name in ae_data.keys() for name in data["Based on AE"].values]]
data[["AE", "Type", "Input Size", "Attempt", "Primary AE Model", "Mask", "Mask Size"]] = [ae_data[based_on] for based_on in data["Based on AE"].values.tolist()]

data[data["Processed Classifier"] == "Discriminator_Thresh_30"]["Type"]
data.head()
# Out:
#       Based on AE  sigma  precision  recall   f-score  max_iter  auc  \
# 0  20240209103156    0.8   0.517241  0.9375  0.666667       NaN  NaN
# 1  20240209103156    1.0   0.481481  0.8125  0.604651       NaN  NaN
# 2  20240209103156    1.2   0.416667  0.6250  0.500000       NaN  NaN
# 3  20240209103156    1.4   0.263158  0.3125  0.285714       NaN  NaN
# 4  20240209103156    1.6   0.176471  0.1875  0.181818       NaN  NaN
#
#    n_estimators  max_depth  min_samples_leaf  ...  n_bins  \
# 0           NaN        NaN               NaN  ...     NaN
# 1           NaN        NaN               NaN  ...     NaN
# 2           NaN        NaN               NaN  ...     NaN
# 3           NaN        NaN               NaN  ...     NaN
# 4           NaN        NaN               NaN  ...     NaN
#
#            Processed Classifier             Dataset              AE  \
# 0  ReconstructionThreshold_0.80  Task 2 (50% Noise)  20240209103156
# 1  ReconstructionThreshold_1.00  Task 2 (50% Noise)  20240209103156
# 2  ReconstructionThreshold_1.20  Task 2 (50% Noise)  20240209103156
# 3  ReconstructionThreshold_1.40  Task 2 (50% Noise)  20240209103156
# 4  ReconstructionThreshold_1.60  Task 2 (50% Noise)  20240209103156
#
#              Type Input Size  Attempt  Primary AE Model   Mask  Mask Size
# 0  Adversarial AE       4096        0    20240209103156  False        0.5
# 1  Adversarial AE       4096        0    20240209103156  False        0.5
# 2  Adversarial AE       4096        0    20240209103156  False        0.5
# 3  Adversarial AE       4096        0    20240209103156  False        0.5
# 4  Adversarial AE       4096        0    20240209103156  False        0.5
#
# [5 rows x 31 columns]

# %%
# Create groups and check if hyper-params are the same
hyper_params_to_check = [
    "max_iter",
    "n_estimators",
    "max_depth",
    "min_samples_leaf",
    "numEstimators",
    "C",
    "gamma",
    "kernel",
    "probability",
    "algorithm",
    "leaf_size",
    "n_neighbors",
    "n_bins",
    "sigma_base",
    "sigma_mult",
    "sigma",
]

data_uniqueness = data[["Primary AE Model", "Processed Classifier"] + hyper_params_to_check]
data_uniqueness = data_uniqueness.groupby(["Primary AE Model", "Processed Classifier"], group_keys=False).nunique()
data_uniqueness["HP Match"] = [all([n<=1 for n in v]) for v in data_uniqueness.values]

data_uniqueness = {(i[0], i[1]): same_hp for i, same_hp in zip(data_uniqueness.index.values, data_uniqueness["HP Match"].values)}

data["HP Match"] = [data_uniqueness[b_ae, pc] for b_ae, pc in data[["Primary AE Model", "Processed Classifier"]].values]
data["Classifier"] = data["Processed Classifier"]
data = data.drop(columns=["Processed Classifier"])

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Attempt", "HP Match", "precision", "recall", "f-score", "auc"]]

data.head()
# Out:
#               Dataset            Type Input Size Primary AE Model  \
# 0  Task 2 (50% Noise)  Adversarial AE       4096   20240209103156
# 1  Task 2 (50% Noise)  Adversarial AE       4096   20240209103156
# 2  Task 2 (50% Noise)  Adversarial AE       4096   20240209103156
# 3  Task 2 (50% Noise)  Adversarial AE       4096   20240209103156
# 4  Task 2 (50% Noise)  Adversarial AE       4096   20240209103156
#
#                AE                    Classifier Attempt  HP Match  precision  \
# 0  20240209103156  ReconstructionThreshold_0.80       0      True   0.517241
# 1  20240209103156  ReconstructionThreshold_1.00       0      True   0.481481
# 2  20240209103156  ReconstructionThreshold_1.20       0      True   0.416667
# 3  20240209103156  ReconstructionThreshold_1.40       0      True   0.263158
# 4  20240209103156  ReconstructionThreshold_1.60       0      True   0.176471
#
#    recall   f-score  auc
# 0  0.9375  0.666667  NaN
# 1  0.8125  0.604651  NaN
# 2  0.6250  0.500000  NaN
# 3  0.3125  0.285714  NaN
# 4  0.1875  0.181818  NaN

# %%
# Rename p, r and f1
data = data.rename(columns={"precision": "Precision", "recall": "Recall", "f-score": "F1-Score", "auc": "Area Under Curve"})

# %%
# Create final table
def row_max(df):
    max_f1 = df["F1-Score"].max()
    return df[df["F1-Score"] == max_f1].iloc[0]

if ALLOW_ONLY_HP_MATCHES:
    data = data[data["HP Match"]]

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Precision", "Recall", "F1-Score", "Area Under Curve"]]
data_std = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].std()
aes = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])["AE"].apply(lambda x : ":".join(["%d" % i for i in x]))
data = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].mean()

data[["Precision Standard Deviation", "Recall Standard Deviation", "F1-Score Standard Deviation", "Area Under Curve Standard Deviation"]] = data_std[["Precision", "Recall", "F1-Score", "Area Under Curve"]]
data["Autoencoders"] = aes
data["AE Count"] = [len(v.split(":")) for v in data["Autoencoders"].values]
print(data["AE Count"].max())
data = data[data["AE Count"] >= TRIALS_REQUIRED]

data = data[~((data["Recall"] == 1) & (data["Precision"] < 0.6))]

data = data.groupby(["Dataset", "Input Size", "Type", "Classifier"]).apply(row_max)

formated_strings = ["%.4f (%.4f, %.4f)" % (f, p, r) for p, r, f in data[["Precision", "Recall", "F1-Score"]].values]
data["Formated Results"] = formated_strings
data = data.sort_values(["Type", "Input Size", "F1-Score"], ascending=False)

data.head()
# Out:
# 6
#                                                                                    Precision  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                          1.000000
#                                                        GMM                          0.833333
#                                                        LogisticRegression           0.888889
#                                                        XGBClassifier                0.762500
#                                                        GradientBoostingClassifier   0.750000
#
#                                                                                      Recall  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.000000
#                                                        GMM                         1.000000
#                                                        LogisticRegression          0.888889
#                                                        XGBClassifier               0.916667
#                                                        GradientBoostingClassifier  0.900000
#
#                                                                                    F1-Score  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.000000
#                                                        GMM                         0.903030
#                                                        LogisticRegression          0.866667
#                                                        XGBClassifier               0.829365
#                                                        GradientBoostingClassifier  0.811111
#
#                                                                                    Area Under Curve  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                 1.000000
#                                                        GMM                                 0.500000
#                                                        LogisticRegression                  0.687500
#                                                        XGBClassifier                       0.763889
#                                                        GradientBoostingClassifier          0.768056
#
#                                                                                    Precision Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                             0.000000
#                                                        GMM                                             0.166667
#                                                        LogisticRegression                              0.192450
#                                                        XGBClassifier                                   0.205649
#                                                        GradientBoostingClassifier                      0.165831
#
#                                                                                    Recall Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                          0.000000
#                                                        GMM                                          0.000000
#                                                        LogisticRegression                           0.192450
#                                                        XGBClassifier                                0.166667
#                                                        GradientBoostingClassifier                   0.136931
#
#                                                                                    F1-Score Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                            0.000000
#                                                        GMM                                            0.100138
#                                                        LogisticRegression                             0.115470
#                                                        XGBClassifier                                  0.182540
#                                                        GradientBoostingClassifier                     0.132346
#
#                                                                                    Area Under Curve Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                                    0.000000
#                                                        GMM                                                    0.000000
#                                                        LogisticRegression                                     0.441942
#                                                        XGBClassifier                                          0.205537
#                                                        GradientBoostingClassifier                             0.243630
#
#                                                                                                                         Autoencoders  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         20240228115759:20240228120005:20240228120231:2...
#                                                        GMM                              20240228133608:20240228133818:20240228134500
#                                                        LogisticRegression               20240228133608:20240228133818:20240228134500
#                                                        XGBClassifier               20240228152834:20240228153240:20240228153452:2...
#                                                        GradientBoostingClassifier  20240228115759:20240228120005:20240228120231:2...
#
#                                                                                    AE Count  \
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                5
#                                                        GMM                                3
#                                                        LogisticRegression                 3
#                                                        XGBClassifier                      4
#                                                        GradientBoostingClassifier         5
#
#                                                                                           Formated Results
# Dataset            Input Size Type                     Classifier
# Task 2 (50% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.0000 (1.0000, 1.0000)
#                                                        GMM                         0.9030 (0.8333, 1.0000)
#                                                        LogisticRegression          0.8667 (0.8889, 0.8889)
#                                                        XGBClassifier               0.8294 (0.7625, 0.9167)
#                                                        GradientBoostingClassifier  0.8111 (0.7500, 0.9000)

# %%
# Save final table

data.to_csv("Final LL Classifiers Table.csv")
