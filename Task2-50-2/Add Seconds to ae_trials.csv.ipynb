# %%
# Load data
import pandas as pd

data = pd.read_csv("ae_trials.csv")
data.head()
# Out:
#              name             dataset            type  attempt        leader  \
# 0  20230224064230  Task 2 (50% Noise)  Adversarial AE        0           NaN
# 1  20230224064455  Task 2 (50% Noise)      Vanilla AE        0  2.023022e+13
# 2  20230224064625  Task 2 (50% Noise)  Adversarial AE        1  2.023022e+13
# 3  20230224064914  Task 2 (50% Noise)      Vanilla AE        1  2.023022e+13
# 4  20230224065042  Task 2 (50% Noise)  Adversarial AE        2  2.023022e+13
#
#    input_size  hidden_layers  hidden_layers_divisor  z_layer_divisor  dropout  \
# 0        4096              2                      2                8      0.5
# 1        4096              2                      2                8      0.5
# 2        4096              2                      2                8      0.5
# 3        4096              2                      2                8      0.5
# 4        4096              2                      2                8      0.5
#
# ...

# %%
data["len"] = [1 for d in data.values]

data.to_csv("ae_trials.csv")
