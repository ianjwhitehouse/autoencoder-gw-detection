# %%
# Load data
import pandas as pd

data = pd.read_csv("ae_trials.csv")
data.head()
# Out:
#              name             dataset            type  attempt        leader  \
# 0  20230224014423  Task 2 (25% Noise)  Adversarial AE        0           NaN
# 1  20230224014528  Task 2 (25% Noise)      Vanilla AE        0  2.023022e+13
# 2  20230224014606  Task 2 (25% Noise)  Adversarial AE        1  2.023022e+13
# 3  20230224014651  Task 2 (25% Noise)      Vanilla AE        1  2.023022e+13
# 4  20230224014744  Task 2 (25% Noise)  Adversarial AE        2  2.023022e+13
#
#    input_size  hidden_layers  hidden_layers_divisor  z_layer_divisor  dropout  \
# 0        4096              2                      2               16     0.25
# 1        4096              2                      2               16     0.25
# 2        4096              2                      2               16     0.25
# 3        4096              2                      2               16     0.25
# 4        4096              2                      2               16     0.25
#
# ...

# %%
data["len"] = [1 for d in data.values]

data.to_csv("ae_trials.csv")
