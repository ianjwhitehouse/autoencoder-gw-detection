# %%
# Set constants
DATASET = "Task 2 (25% Noise)"
ALLOW_ONLY_HP_MATCHES = True
TRIALS_REQUIRED = 3
DIFFERENCE_THRESHS = [1.05, 1.1, 1.5, 3, 4.5]

# %%
# Load data
import pandas as pd

data = pd.read_csv("latent_trials.csv")
data.head()
# Out:
# /tmp/ipykernel_132799/3332622169.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                    Classifier     Based on AE  n_estimators  precision  \
# 0        ExtraTreesClassifier  20240209085949         100.0   0.666667
# 1      RandomForestClassifier  20240209085949         100.0   0.666667
# 2  GradientBoostingClassifier  20240209085949           NaN   0.500000
# 3               XGBClassifier  20240209085949           NaN   1.000000
# 4                         SVC  20240209085949           NaN   1.000000
#
#    recall  f-score    auc  max_depth  min_samples_leaf  numEstimators  ...  \
# 0     1.0      0.8  1.000        NaN               NaN            NaN  ...
# 1     1.0      0.8  1.000        NaN               NaN            NaN  ...
# 2     0.5      0.5  0.625        5.0               1.0            NaN  ...
# 3     1.0      1.0  1.000        NaN               NaN         1000.0  ...
# 4     1.0      1.0  1.000        NaN               NaN            NaN  ...
#
#    probability  contamination n_neighbors sigma  max_iter  algorithm  \
# 0          NaN            NaN         NaN   NaN       NaN        NaN
# 1          NaN            NaN         NaN   NaN       NaN        NaN
# 2          NaN            NaN         NaN   NaN       NaN        NaN
# 3          NaN            NaN         NaN   NaN       NaN        NaN
# 4         True            NaN         NaN   NaN       NaN        NaN
#
#    leaf_size  sigma_base sigma_mult  n_bins
# 0        NaN         NaN        NaN     NaN
# 1        NaN         NaN        NaN     NaN
# 2        NaN         NaN        NaN     NaN
# 3        NaN         NaN        NaN     NaN
# 4        NaN         NaN        NaN     NaN
#
# [5 rows x 23 columns]

# %%
# Add processed classifer column
data["Processed Classifier"] = [classifier + "_%.2f" % sigma if classifier == "ReconstructionThreshold" else classifier for classifier, sigma in data[["Classifier", "sigma"]].values]
# data["Processed Classifier"] = data["Classifier"]
data = data.drop(columns=["Classifier"])

data["Dataset"] = [DATASET for _ in data.index]

# %%
# Add AE data

ae_data = pd.read_csv("ae_trials.csv", keep_default_na=False)
ae_data = ae_data[["name", "type", "input_size", "attempt", "leader" , "masking", "mask_size"]]
ae_data["Primary Model"] = ["%d" % float(leader) if leader else "%d" % float(base) for base, leader in ae_data[["name", "leader"]].values]
ae_data = ae_data.drop(columns=["leader"])

ae_data["type"] = [type + " (%.2f Masked)" % mask_size if mask else type for type, mask, mask_size in ae_data[["type", "masking", "mask_size"]].values]

ae_data.head()
# Out:
#              name                          type  input_size  attempt  masking  \
# 0  20240209090044  Adversarial AE (0.75 Masked)        4096        0     True
# 1  20240209090138      Vanilla AE (0.75 Masked)        4096        0     True
# 2  20240209090239  Adversarial AE (0.75 Masked)        4096        1     True
# 3  20240209090333      Vanilla AE (0.75 Masked)        4096        1     True
# 4  20240209090432  Adversarial AE (0.75 Masked)        4096        2     True
#
#    mask_size   Primary Model
# 0       0.75  20240209090044
# 1       0.75  20240209090044
# 2       0.75  20240209090044
# 3       0.75  20240209090044
# 4       0.75  20240209090044

# %%
# Convert AE data to dict and add to ll data

ae_data = {name: [name, ae_type, input_size, attempt, primary, masking, mask_size] for name, ae_type, input_size, attempt, masking, mask_size, primary in ae_data.values}
data = data[[name in ae_data.keys() for name in data["Based on AE"].values]]
data[["AE", "Type", "Input Size", "Attempt", "Primary AE Model", "Mask", "Mask Size"]] = [ae_data[based_on] for based_on in data["Based on AE"].values.tolist()]

data[data["Processed Classifier"] == "Discriminator_Thresh_30"]["Type"]
data.head()
# Out:
#        Based on AE  n_estimators  precision  recall  f-score  auc  max_depth  \
# 7   20240209090044           NaN        0.0     0.0      0.0  NaN        NaN
# 8   20240209090044           NaN        0.0     0.0      0.0  NaN        NaN
# 9   20240209090044           NaN        0.0     0.0      0.0  NaN        NaN
# 10  20240209090044           NaN        0.0     0.0      0.0  NaN        NaN
# 11  20240209090044           NaN        0.0     0.0      0.0  NaN        NaN
#
#     min_samples_leaf  numEstimators   C  ...  n_bins  \
# 7                NaN            NaN NaN  ...     NaN
# 8                NaN            NaN NaN  ...     NaN
# 9                NaN            NaN NaN  ...     NaN
# 10               NaN            NaN NaN  ...     NaN
# 11               NaN            NaN NaN  ...     NaN
#
#             Processed Classifier             Dataset              AE  \
# 7   ReconstructionThreshold_0.80  Task 2 (25% Noise)  20240209090044
# 8   ReconstructionThreshold_1.00  Task 2 (25% Noise)  20240209090044
# 9   ReconstructionThreshold_1.20  Task 2 (25% Noise)  20240209090044
# 10  ReconstructionThreshold_1.40  Task 2 (25% Noise)  20240209090044
# 11  ReconstructionThreshold_1.60  Task 2 (25% Noise)  20240209090044
#
#                             Type  Input Size  Attempt Primary AE Model  Mask  \
# 7   Adversarial AE (0.75 Masked)        4096        0   20240209090044  True
# 8   Adversarial AE (0.75 Masked)        4096        0   20240209090044  True
# 9   Adversarial AE (0.75 Masked)        4096        0   20240209090044  True
# 10  Adversarial AE (0.75 Masked)        4096        0   20240209090044  True
# 11  Adversarial AE (0.75 Masked)        4096        0   20240209090044  True
#
#     Mask Size
# 7        0.75
# 8        0.75
# 9        0.75
# 10       0.75
# 11       0.75
#
# [5 rows x 31 columns]

# %%
# Create groups and check if hyper-params are the same
hyper_params_to_check = [
    "max_iter",
    "n_estimators",
    "max_depth",
    "min_samples_leaf",
    "numEstimators",
    "C",
    "gamma",
    "kernel",
    "probability",
    "algorithm",
    "leaf_size",
    "n_neighbors",
    "n_bins",
    "sigma_base",
    "sigma_mult",
    "sigma",
]

data_uniqueness = data[["Primary AE Model", "Processed Classifier"] + hyper_params_to_check]
data_uniqueness = data_uniqueness.groupby(["Primary AE Model", "Processed Classifier"], group_keys=False).nunique()
data_uniqueness["HP Match"] = [all([n<=1 for n in v]) for v in data_uniqueness.values]

data_uniqueness = {(i[0], i[1]): same_hp for i, same_hp in zip(data_uniqueness.index.values, data_uniqueness["HP Match"].values)}

data["HP Match"] = [data_uniqueness[b_ae, pc] for b_ae, pc in data[["Primary AE Model", "Processed Classifier"]].values]
data["Classifier"] = data["Processed Classifier"]
data = data.drop(columns=["Processed Classifier"])

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Attempt", "HP Match", "precision", "recall", "f-score", "auc"]]

data.head()
# Out:
#                Dataset                          Type Input Size  \
# 7   Task 2 (25% Noise)  Adversarial AE (0.75 Masked)       4096
# 8   Task 2 (25% Noise)  Adversarial AE (0.75 Masked)       4096
# 9   Task 2 (25% Noise)  Adversarial AE (0.75 Masked)       4096
# 10  Task 2 (25% Noise)  Adversarial AE (0.75 Masked)       4096
# 11  Task 2 (25% Noise)  Adversarial AE (0.75 Masked)       4096
#
#    Primary AE Model              AE                    Classifier Attempt  \
# 7    20240209090044  20240209090044  ReconstructionThreshold_0.80       0
# 8    20240209090044  20240209090044  ReconstructionThreshold_1.00       0
# 9    20240209090044  20240209090044  ReconstructionThreshold_1.20       0
# 10   20240209090044  20240209090044  ReconstructionThreshold_1.40       0
# 11   20240209090044  20240209090044  ReconstructionThreshold_1.60       0
#
#     HP Match  precision  recall  f-score  auc
# 7       True        0.0     0.0      0.0  NaN
# 8       True        0.0     0.0      0.0  NaN
# 9       True        0.0     0.0      0.0  NaN
# 10      True        0.0     0.0      0.0  NaN
# 11      True        0.0     0.0      0.0  NaN

# %%
# Rename p, r and f1
data = data.rename(columns={"precision": "Precision", "recall": "Recall", "f-score": "F1-Score", "auc": "Area Under Curve"})

# %%
# Create final table
def row_max(df):
    max_f1 = df["F1-Score"].max()
    return df[df["F1-Score"] == max_f1].iloc[0]

if ALLOW_ONLY_HP_MATCHES:
    data = data[data["HP Match"]]

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Precision", "Recall", "F1-Score", "Area Under Curve"]]
data_std = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].std()
aes = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])["AE"].apply(lambda x : ":".join(["%d" % i for i in x]))
data = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].mean()

data[["Precision Standard Deviation", "Recall Standard Deviation", "F1-Score Standard Deviation", "Area Under Curve Standard Deviation"]] = data_std[["Precision", "Recall", "F1-Score", "Area Under Curve"]]
data["Autoencoders"] = aes
data["AE Count"] = [len(v.split(":")) for v in data["Autoencoders"].values]
print(data["AE Count"].max())
data = data[data["AE Count"] >= TRIALS_REQUIRED]

data = data[~((data["Recall"] == 1) & (data["Precision"] < 0.6))]

data = data.groupby(["Dataset", "Input Size", "Type", "Classifier"]).apply(row_max)

formated_strings = ["%.4f (%.4f, %.4f)" % (f, p, r) for p, r, f in data[["Precision", "Recall", "F1-Score"]].values]
data["Formated Results"] = formated_strings
data = data.sort_values(["Type", "Input Size", "F1-Score"], ascending=False)

data.head()
# Out:
# 6
#                                                                                    Precision  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                          1.000000
#                                                        XGBClassifier                0.916667
#                                                        GradientBoostingClassifier   0.850000
#                                                        GMM                          0.833333
#                                                        LogisticRegression           0.888889
#
#                                                                                      Recall  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.000000
#                                                        XGBClassifier               1.000000
#                                                        GradientBoostingClassifier  1.000000
#                                                        GMM                         1.000000
#                                                        LogisticRegression          0.933333
#
#                                                                                    F1-Score  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.000000
#                                                        XGBClassifier               0.952381
#                                                        GradientBoostingClassifier  0.909722
#                                                        GMM                         0.903030
#                                                        LogisticRegression          0.896296
#
#                                                                                    Area Under Curve  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                 1.000000
#                                                        XGBClassifier                       0.888889
#                                                        GradientBoostingClassifier          0.937500
#                                                        GMM                                 0.500000
#                                                        LogisticRegression                  0.958333
#
#                                                                                    Precision Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                             0.000000
#                                                        XGBClassifier                                   0.144338
#                                                        GradientBoostingClassifier                      0.191485
#                                                        GMM                                             0.166667
#                                                        LogisticRegression                              0.192450
#
#                                                                                    Recall Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                           0.00000
#                                                        XGBClassifier                                 0.00000
#                                                        GradientBoostingClassifier                    0.00000
#                                                        GMM                                           0.00000
#                                                        LogisticRegression                            0.11547
#
#                                                                                    F1-Score Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                            0.000000
#                                                        XGBClassifier                                  0.082479
#                                                        GradientBoostingClassifier                     0.118667
#                                                        GMM                                            0.100138
#                                                        LogisticRegression                             0.100206
#
#                                                                                    Area Under Curve Standard Deviation  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                                    0.000000
#                                                        XGBClassifier                                          0.192450
#                                                        GradientBoostingClassifier                             0.125000
#                                                        GMM                                                    0.000000
#                                                        LogisticRegression                                     0.072169
#
#                                                                                                                         Autoencoders  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         20240223144434:20240223144649:20240223144905:2...
#                                                        XGBClassifier                    20240225012706:20240225013252:20240225013812
#                                                        GradientBoostingClassifier  20240225095015:20240225100416:20240225100707:2...
#                                                        GMM                              20240227035011:20240227035346:20240227040032
#                                                        LogisticRegression               20240225095015:20240225100416:20240225100707
#
#                                                                                    AE Count  \
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                                5
#                                                        XGBClassifier                      3
#                                                        GradientBoostingClassifier         4
#                                                        GMM                                3
#                                                        LogisticRegression                 3
#
#                                                                                           Formated Results
# Dataset            Input Size Type                     Classifier
# Task 2 (25% Noise) 12288      Vanilla AE (0.75 Masked) SVC                         1.0000 (1.0000, 1.0000)
#                                                        XGBClassifier               0.9524 (0.9167, 1.0000)
#                                                        GradientBoostingClassifier  0.9097 (0.8500, 1.0000)
#                                                        GMM                         0.9030 (0.8333, 1.0000)
#                                                        LogisticRegression          0.8963 (0.8889, 0.9333)

# %%
# Save final table

data.to_csv("Final LL Classifiers Table.csv")
