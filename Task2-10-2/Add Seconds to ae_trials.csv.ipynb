# %%
# Load data
import pandas as pd

data = pd.read_csv("ae_trials.csv")
data.head()
# Out:
#              name             dataset            type  attempt        leader  \
# 0  20230223203432  Task 2 (10% Noise)  Adversarial AE        0           NaN
# 1  20230223203614  Task 2 (10% Noise)      Vanilla AE        0  2.023022e+13
# 2  20230223203727  Task 2 (10% Noise)  Adversarial AE        1  2.023022e+13
# 3  20230223203909  Task 2 (10% Noise)      Vanilla AE        1  2.023022e+13
# 4  20230223204022  Task 2 (10% Noise)  Adversarial AE        2  2.023022e+13
#
#    input_size  hidden_layers  hidden_layers_divisor  z_layer_divisor  dropout  \
# 0        4096              1                      2                8      0.1
# 1        4096              1                      2                8      0.1
# 2        4096              1                      2                8      0.1
# 3        4096              1                      2                8      0.1
# 4        4096              1                      2                8      0.1
#
# ...

# %%
data["len"] = [1 for d in data.values]

data.to_csv("ae_trials.csv")
