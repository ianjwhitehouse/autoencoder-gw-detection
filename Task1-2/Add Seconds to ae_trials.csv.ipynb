# %%
# Load data
import pandas as pd

data = pd.read_csv("ae_trials.csv")
data.head()
# Out:
#              name dataset            type  attempt        leader  input_size  \
# 0  20230223145652  Task 1  Adversarial AE        0           NaN        4096
# 1  20230223150008  Task 1      Vanilla AE        0  2.023022e+13        4096
# 2  20230223150136  Task 1  Adversarial AE        1  2.023022e+13        4096
# 3  20230223150448  Task 1      Vanilla AE        1  2.023022e+13        4096
# 4  20230223150615  Task 1  Adversarial AE        2  2.023022e+13        4096
#
#    hidden_layers  hidden_layers_divisor  z_layer_divisor  dropout  \
# 0              2                      8                4     0.25
# 1              2                      8                4     0.25
# 2              2                      8                4     0.25
# 3              2                      8                4     0.25
# 4              2                      8                4     0.25
#
#    learning_rate  batch_size  gen_loss  disc_loss  val_loss  epochs
# ...

# %%
data["len"] = [1 for d in data.values]

data.to_csv("ae_trials.csv")
