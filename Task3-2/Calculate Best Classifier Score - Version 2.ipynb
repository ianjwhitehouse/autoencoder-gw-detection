# %%
# Set constants
DATASET = "Task 3"
ALLOW_ONLY_HP_MATCHES = True
TRIALS_REQUIRED = 3
DIFFERENCE_THRESHS = [1.05, 1.1, 1.5, 3, 4.5]

# %%
# Load data
import pandas as pd

data = pd.read_csv("latent_trials.csv")
data.head()
# Out:
#                 Classifier     Based on AE  sigma  precision    recall  \
# 0  ReconstructionThreshold  20240209141704    0.8   0.434783  0.740741
# 1  ReconstructionThreshold  20240209141704    1.0   0.472222  0.629630
# 2  ReconstructionThreshold  20240209141704    1.2   0.555556  0.555556
# 3  ReconstructionThreshold  20240209141704    1.4   0.578947  0.407407
# 4  ReconstructionThreshold  20240209141704    1.6   0.500000  0.222222
#
#     f-score  max_iter  auc  n_estimators  max_depth  ...  gamma  kernel  \
# 0  0.547945       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 1  0.539683       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 2  0.555556       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 3  0.478261       NaN  NaN           NaN        NaN  ...    NaN     NaN
# 4  0.307692       NaN  NaN           NaN        NaN  ...    NaN     NaN
#
#    probability  algorithm leaf_size n_neighbors contamination  n_bins  \
# 0          NaN        NaN       NaN         NaN           NaN     NaN
# 1          NaN        NaN       NaN         NaN           NaN     NaN
# 2          NaN        NaN       NaN         NaN           NaN     NaN
# 3          NaN        NaN       NaN         NaN           NaN     NaN
# 4          NaN        NaN       NaN         NaN           NaN     NaN
#
#    sigma_base  sigma_mult
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 23 columns]

# %%
# Add processed classifer column
data["Processed Classifier"] = [classifier + "_%.2f" % sigma if classifier == "ReconstructionThreshold" else classifier for classifier, sigma in data[["Classifier", "sigma"]].values]
# data["Processed Classifier"] = data["Classifier"]
data = data.drop(columns=["Classifier"])

data["Dataset"] = [DATASET for _ in data.index]

# %%
# Add AE data

ae_data = pd.read_csv("ae_trials.csv", keep_default_na=False)
ae_data = ae_data[["name", "type", "input_size", "attempt", "leader" , "masking", "mask_size"]]
ae_data["Primary Model"] = ["%d" % float(leader) if leader else "%d" % float(base) for base, leader in ae_data[["name", "leader"]].values]
ae_data = ae_data.drop(columns=["leader"])

ae_data["type"] = [type + " (%.2f Masked)" % mask_size if mask else type for type, mask, mask_size in ae_data[["type", "masking", "mask_size"]].values]

ae_data.head()
# Out:
#              name                          type  input_size  attempt  masking  \
# 0  20240209141704  Adversarial AE (0.25 Masked)       12288        0     True
# 1  20240209141849  Adversarial AE (0.25 Masked)       12288        0     True
# 2  20240209141955  Adversarial AE (0.75 Masked)       12288        0     True
# 3  20240212142033  Adversarial AE (0.50 Masked)       12288        0     True
# 4  20240212142411                Adversarial AE       12288        0    False
#
#    mask_size   Primary Model
# 0       0.25  20240209141704
# 1       0.25  20240209141849
# 2       0.75  20240209141955
# 3       0.50  20240212142033
# 4       0.25  20240212142411

# %%
# Convert AE data to dict and add to ll data

ae_data = {name: [name, ae_type, input_size, attempt, primary, masking, mask_size] for name, ae_type, input_size, attempt, masking, mask_size, primary in ae_data.values}
data = data[[name in ae_data.keys() for name in data["Based on AE"].values]]
data[["AE", "Type", "Input Size", "Attempt", "Primary AE Model", "Mask", "Mask Size"]] = [ae_data[based_on] for based_on in data["Based on AE"].values.tolist()]

data[data["Processed Classifier"] == "Discriminator_Thresh_30"]["Type"]
data.head()
# Out:
#       Based on AE  sigma  precision    recall   f-score  max_iter  auc  \
# 0  20240209141704    0.8   0.434783  0.740741  0.547945       NaN  NaN
# 1  20240209141704    1.0   0.472222  0.629630  0.539683       NaN  NaN
# 2  20240209141704    1.2   0.555556  0.555556  0.555556       NaN  NaN
# 3  20240209141704    1.4   0.578947  0.407407  0.478261       NaN  NaN
# 4  20240209141704    1.6   0.500000  0.222222  0.307692       NaN  NaN
#
#    n_estimators  max_depth  min_samples_leaf  ...  sigma_mult  \
# 0           NaN        NaN               NaN  ...         NaN
# 1           NaN        NaN               NaN  ...         NaN
# 2           NaN        NaN               NaN  ...         NaN
# 3           NaN        NaN               NaN  ...         NaN
# 4           NaN        NaN               NaN  ...         NaN
#
#            Processed Classifier  Dataset              AE  \
# 0  ReconstructionThreshold_0.80   Task 3  20240209141704
# 1  ReconstructionThreshold_1.00   Task 3  20240209141704
# 2  ReconstructionThreshold_1.20   Task 3  20240209141704
# 3  ReconstructionThreshold_1.40   Task 3  20240209141704
# 4  ReconstructionThreshold_1.60   Task 3  20240209141704
#
#                            Type Input Size  Attempt  Primary AE Model  Mask  \
# 0  Adversarial AE (0.25 Masked)      12288        0    20240209141704  True
# 1  Adversarial AE (0.25 Masked)      12288        0    20240209141704  True
# 2  Adversarial AE (0.25 Masked)      12288        0    20240209141704  True
# 3  Adversarial AE (0.25 Masked)      12288        0    20240209141704  True
# 4  Adversarial AE (0.25 Masked)      12288        0    20240209141704  True
#
#    Mask Size
# 0       0.25
# 1       0.25
# 2       0.25
# 3       0.25
# 4       0.25
#
# [5 rows x 31 columns]

# %%
# Create groups and check if hyper-params are the same
hyper_params_to_check = [
    "max_iter",
    "n_estimators",
    "max_depth",
    "min_samples_leaf",
    "numEstimators",
    "C",
    "gamma",
    "kernel",
    "probability",
    "algorithm",
    "leaf_size",
    "n_neighbors",
    "n_bins",
    # "sigma_base",
    # "sigma_mult",
    "sigma",
]

data_uniqueness = data[["Primary AE Model", "Processed Classifier"] + hyper_params_to_check]
data_uniqueness = data_uniqueness.groupby(["Primary AE Model", "Processed Classifier"], group_keys=False).nunique()
data_uniqueness["HP Match"] = [all([n<=1 for n in v]) for v in data_uniqueness.values]

data_uniqueness = {(i[0], i[1]): same_hp for i, same_hp in zip(data_uniqueness.index.values, data_uniqueness["HP Match"].values)}

data["HP Match"] = [data_uniqueness[b_ae, pc] for b_ae, pc in data[["Primary AE Model", "Processed Classifier"]].values]
data["Classifier"] = data["Processed Classifier"]
data = data.drop(columns=["Processed Classifier"])

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Attempt", "HP Match", "precision", "recall", "f-score", "auc"]]
data.head()
# Out:
#   Dataset                          Type Input Size Primary AE Model  \
# 0  Task 3  Adversarial AE (0.25 Masked)      12288   20240209141704
# 1  Task 3  Adversarial AE (0.25 Masked)      12288   20240209141704
# 2  Task 3  Adversarial AE (0.25 Masked)      12288   20240209141704
# 3  Task 3  Adversarial AE (0.25 Masked)      12288   20240209141704
# 4  Task 3  Adversarial AE (0.25 Masked)      12288   20240209141704
#
#                AE                    Classifier Attempt  HP Match  precision  \
# 0  20240209141704  ReconstructionThreshold_0.80       0      True   0.434783
# 1  20240209141704  ReconstructionThreshold_1.00       0      True   0.472222
# 2  20240209141704  ReconstructionThreshold_1.20       0      True   0.555556
# 3  20240209141704  ReconstructionThreshold_1.40       0      True   0.578947
# 4  20240209141704  ReconstructionThreshold_1.60       0      True   0.500000
#
#      recall   f-score  auc
# 0  0.740741  0.547945  NaN
# 1  0.629630  0.539683  NaN
# 2  0.555556  0.555556  NaN
# 3  0.407407  0.478261  NaN
# 4  0.222222  0.307692  NaN

# %%
# Rename p, r and f1
data = data.rename(columns={"precision": "Precision", "recall": "Recall", "f-score": "F1-Score", "auc": "Area Under Curve"})

# %%
# Create final table
def row_max(df):
    max_f1 = df["F1-Score"].max()
    return df[df["F1-Score"] == max_f1].iloc[0]

if ALLOW_ONLY_HP_MATCHES:
    data = data[data["HP Match"]]

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "AE", "Classifier", "Precision", "Recall", "F1-Score", "Area Under Curve"]]
data_std = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].std()
aes = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])["AE"].apply(lambda x : ":".join(["%d" % i for i in x]))
data = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"])[["Precision", "Recall", "F1-Score", "Area Under Curve"]].mean()

data[["Precision Standard Deviation", "Recall Standard Deviation", "F1-Score Standard Deviation", "Area Under Curve Standard Deviation"]] = data_std[["Precision", "Recall", "F1-Score", "Area Under Curve"]]
data["Autoencoders"] = aes
data["AE Count"] = [len(v.split(":")) for v in data["Autoencoders"].values]
print(data["AE Count"].max())
data = data[data["AE Count"] >= TRIALS_REQUIRED]

data = data[~((data["Recall"] == 1) & (data["Precision"] < 0.6))]

data = data.groupby(["Dataset", "Input Size", "Type", "Classifier"]).apply(row_max)

formated_strings = ["%.4f (%.4f, %.4f)" % (f, p, r) for p, r, f in data[["Precision", "Recall", "F1-Score"]].values]
data["Formated Results"] = formated_strings
data = data.sort_values(["Type", "Input Size", "F1-Score"], ascending=False)

data
# Out:
# 5
#                                                                           Precision  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00   0.470774
#                                             ReconstructionThreshold_1.20   0.504099
#                                             ReconstructionThreshold_0.80   0.426074
#                                             ReconstructionThreshold_1.40   0.518160
#                                             ReconstructionThreshold_2.00   0.885263
# ...                                                                             ...
#                    Adversarial AE           ReconstructionThreshold_5.20   0.240400
#                                             ReconstructionThreshold_5.00   0.239375
#                                             ReconstructionThreshold_5.60   0.239691
#                                             ReconstructionThreshold_5.40   0.238516
#                                             ABOD                           0.000000
#
#                                                                             Recall  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00  0.850074
#                                             ReconstructionThreshold_1.20  0.729208
#                                             ReconstructionThreshold_0.80  0.887704
#                                             ReconstructionThreshold_1.40  0.668764
#                                             ReconstructionThreshold_2.00  0.394553
# ...                                                                            ...
#                    Adversarial AE           ReconstructionThreshold_5.20  0.794142
#                                             ReconstructionThreshold_5.00  0.794142
#                                             ReconstructionThreshold_5.60  0.779043
#                                             ReconstructionThreshold_5.40  0.779043
#                                             ABOD                          0.000000
#
#                                                                           F1-Score  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00  0.599097
#                                             ReconstructionThreshold_1.20  0.585571
#                                             ReconstructionThreshold_0.80  0.571588
#                                             ReconstructionThreshold_1.40  0.569412
#                                             ReconstructionThreshold_2.00  0.539987
# ...                                                                            ...
#                    Adversarial AE           ReconstructionThreshold_5.20  0.368932
#                                             ReconstructionThreshold_5.00  0.367697
#                                             ReconstructionThreshold_5.60  0.366395
#                                             ReconstructionThreshold_5.40  0.365051
#                                             ABOD                          0.000000
#
#                                                                           Area Under Curve  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00               NaN
#                                             ReconstructionThreshold_1.20               NaN
#                                             ReconstructionThreshold_0.80               NaN
#                                             ReconstructionThreshold_1.40               NaN
#                                             ReconstructionThreshold_2.00               NaN
# ...                                                                                    ...
#                    Adversarial AE           ReconstructionThreshold_5.20               NaN
#                                             ReconstructionThreshold_5.00               NaN
#                                             ReconstructionThreshold_5.60               NaN
#                                             ReconstructionThreshold_5.40               NaN
#                                             ABOD                                       0.5
#
#                                                                           Precision Standard Deviation  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00                      0.082598
#                                             ReconstructionThreshold_1.20                      0.063050
#                                             ReconstructionThreshold_0.80                      0.061711
#                                             ReconstructionThreshold_1.40                      0.068650
#                                             ReconstructionThreshold_2.00                      0.205277
# ...                                                                                                ...
#                    Adversarial AE           ReconstructionThreshold_5.20                      0.020211
#                                             ReconstructionThreshold_5.00                      0.020036
#                                             ReconstructionThreshold_5.60                      0.017027
#                                             ReconstructionThreshold_5.40                      0.017466
#                                             ABOD                                              0.000000
#
#                                                                           Recall Standard Deviation  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00                   0.097229
#                                             ReconstructionThreshold_1.20                   0.158246
#                                             ReconstructionThreshold_0.80                   0.077911
#                                             ReconstructionThreshold_1.40                   0.174745
#                                             ReconstructionThreshold_2.00                   0.039505
# ...                                                                                             ...
#                    Adversarial AE           ReconstructionThreshold_5.20                   0.062829
#                                             ReconstructionThreshold_5.00                   0.062829
#                                             ReconstructionThreshold_5.60                   0.055675
#                                             ReconstructionThreshold_5.40                   0.055675
#                                             ABOD                                           0.000000
#
#                                                                           F1-Score Standard Deviation  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00                     0.059678
#                                             ReconstructionThreshold_1.20                     0.058545
#                                             ReconstructionThreshold_0.80                     0.049588
#                                             ReconstructionThreshold_1.40                     0.055031
#                                             ReconstructionThreshold_2.00                     0.070861
# ...                                                                                               ...
#                    Adversarial AE           ReconstructionThreshold_5.20                     0.029581
#                                             ReconstructionThreshold_5.00                     0.029174
#                                             ReconstructionThreshold_5.60                     0.024420
#                                             ReconstructionThreshold_5.40                     0.025253
#                                             ABOD                                             0.000000
#
#                                                                           Area Under Curve Standard Deviation  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00                                  NaN
#                                             ReconstructionThreshold_1.20                                  NaN
#                                             ReconstructionThreshold_0.80                                  NaN
#                                             ReconstructionThreshold_1.40                                  NaN
#                                             ReconstructionThreshold_2.00                                  NaN
# ...                                                                                                       ...
#                    Adversarial AE           ReconstructionThreshold_5.20                                  NaN
#                                             ReconstructionThreshold_5.00                                  NaN
#                                             ReconstructionThreshold_5.60                                  NaN
#                                             ReconstructionThreshold_5.40                                  NaN
#                                             ABOD                                                          0.0
#
#                                                                                                                Autoencoders  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00  20240229000807:20240229001203:20240229001557:2...
#                                             ReconstructionThreshold_1.20  20240229000807:20240229001203:20240229001557:2...
#                                             ReconstructionThreshold_0.80  20240228234047:20240228234652:20240228235238:2...
#                                             ReconstructionThreshold_1.40  20240229000807:20240229001203:20240229001557:2...
#                                             ReconstructionThreshold_2.00  20240229004635:20240229004846:20240229005051:2...
# ...                                                                                                                     ...
#                    Adversarial AE           ReconstructionThreshold_5.20  20240228220642:20240228221015:20240228221406:2...
#                                             ReconstructionThreshold_5.00  20240228220642:20240228221015:20240228221406:2...
#                                             ReconstructionThreshold_5.60  20240228220642:20240228221015:20240228221406:2...
#                                             ReconstructionThreshold_5.40  20240228220642:20240228221015:20240228221406:2...
#                                             ABOD                          20240228220642:20240228221015:20240228221406:2...
#
#                                                                           AE Count  \
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00         5
#                                             ReconstructionThreshold_1.20         5
#                                             ReconstructionThreshold_0.80         5
#                                             ReconstructionThreshold_1.40         5
#                                             ReconstructionThreshold_2.00         5
# ...                                                                            ...
#                    Adversarial AE           ReconstructionThreshold_5.20         5
#                                             ReconstructionThreshold_5.00         5
#                                             ReconstructionThreshold_5.60         5
#                                             ReconstructionThreshold_5.40         5
#                                             ABOD                                 5
#
#                                                                                  Formated Results
# Dataset Input Size Type                     Classifier
# Task 3  4096       Vanilla AE (0.75 Masked) ReconstructionThreshold_1.00  0.5991 (0.4708, 0.8501)
#                                             ReconstructionThreshold_1.20  0.5856 (0.5041, 0.7292)
#                                             ReconstructionThreshold_0.80  0.5716 (0.4261, 0.8877)
#                                             ReconstructionThreshold_1.40  0.5694 (0.5182, 0.6688)
#                                             ReconstructionThreshold_2.00  0.5400 (0.8853, 0.3946)
# ...                                                                                           ...
#                    Adversarial AE           ReconstructionThreshold_5.20  0.3689 (0.2404, 0.7941)
#                                             ReconstructionThreshold_5.00  0.3677 (0.2394, 0.7941)
#                                             ReconstructionThreshold_5.60  0.3664 (0.2397, 0.7790)
#                                             ReconstructionThreshold_5.40  0.3651 (0.2385, 0.7790)
#                                             ABOD                          0.0000 (0.0000, 0.0000)
#
# [446 rows x 11 columns]

# %%
# Save final table

data.to_csv("Final LL Classifiers Table.csv")
