# %%
# Set constants
DATASET = "Task 3"
ALLOW_ONLY_HP_MATCHES = True
DIFFERENCE_THRESHS = [1.05, 1.1, 1.5, 3, 4.5]

# %%
# Load data
import pandas as pd

data = pd.read_csv("latent_trials.csv")
data.head()
# Out:
#                 Classifier     Based on AE  sigma  precision    recall  \
# 0  ReconstructionThreshold  20230224233553   1.05   0.139535  0.222222
# 1  ReconstructionThreshold  20230224233553   1.10   0.139535  0.222222
# 2  ReconstructionThreshold  20230224233553   1.50   0.166667  0.185185
# 3  ReconstructionThreshold  20230224233553   3.00   0.000000  0.000000
# 4  ReconstructionThreshold  20230224233553   4.50   0.000000  0.000000
#
#     f-score  max_iter  auc  n_estimators  max_depth  min_samples_leaf  \
# 0  0.171429       NaN  NaN           NaN        NaN               NaN
# 1  0.171429       NaN  NaN           NaN        NaN               NaN
# 2  0.175439       NaN  NaN           NaN        NaN               NaN
# 3  0.000000       NaN  NaN           NaN        NaN               NaN
# 4  0.000000       NaN  NaN           NaN        NaN               NaN
#
#    numEstimators   C  gamma kernel probability algorithm  leaf_size  \
# 0            NaN NaN    NaN    NaN         NaN       NaN        NaN
# 1            NaN NaN    NaN    NaN         NaN       NaN        NaN
# 2            NaN NaN    NaN    NaN         NaN       NaN        NaN
# 3            NaN NaN    NaN    NaN         NaN       NaN        NaN
# 4            NaN NaN    NaN    NaN         NaN       NaN        NaN
#
#    n_neighbors
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# Add processed classifer column
data["Processed Classifier"] = [classifier + "_" + str(sigma) if classifier == "ReconstructionThreshold" else classifier for classifier, sigma in data[["Classifier", "sigma"]].values]
data = data.drop(columns=["Classifier"])

data["Dataset"] = [DATASET for _ in data.index]

# %%
# Add AE data

ae_data = pd.read_csv("ae_trials.csv", keep_default_na=False)
ae_data = ae_data[["name", "type", "input_size", "attempt", "leader"]]
ae_data["Primary Model"] = ["%d" % float(leader) if leader else "%d" % float(base) for base, leader in ae_data[["name", "leader"]].values]
ae_data = ae_data.drop(columns=["leader"])
ae_data.head()
# Out:
#              name            type  input_size  attempt   Primary Model
# 0  20230224233553  Adversarial AE        4096        0  20230224233553
# 1  20230224234106      Vanilla AE        4096        0  20230224233553
# 2  20230224234323  Adversarial AE        4096        1  20230224233553
# 3  20230224234831      Vanilla AE        4096        1  20230224233553
# 4  20230224235042  Adversarial AE        4096        2  20230224233553

# %%
# Convert AE data to dict and add to ll data

ae_data = {name: [ae_type, input_size, attempt, primary] for name, ae_type, input_size, attempt, primary in ae_data.values}
data = data[[name in ae_data.keys() for name in data["Based on AE"].values]]
data[["Type", "Input Size", "Attempt", "Primary AE Model"]] = [ae_data[name] for name in data["Based on AE"].values]

data[data["Processed Classifier"] == "Discriminator_Thresh_30"]["Type"]
# Out:
# 9       Adversarial AE
# 41      Adversarial AE
# 73      Adversarial AE
# 105     Adversarial AE
# 137     Adversarial AE
#              ...
# 3081    Adversarial AE
# 3113    Adversarial AE
# 3145    Adversarial AE
# 3177    Adversarial AE
# 3209    Adversarial AE
# Name: Type, Length: 101, dtype: object

# %%
# Create groups and check if hyper-params are the same
hyper_params_to_check = [
    "max_iter",
    "n_estimators",
    "max_depth",
    "min_samples_leaf",
    "numEstimators",
    "C",
    "gamma",
    "kernel",
    "probability",
    "algorithm",
    "leaf_size",
    "n_neighbors"
]

data_uniqueness = data[["Primary AE Model", "Processed Classifier"] + hyper_params_to_check]
data_uniqueness = data_uniqueness.groupby(["Primary AE Model", "Processed Classifier"], group_keys=False).nunique()
data_uniqueness["HP Match"] = [all([n<=1 for n in v]) for v in data_uniqueness.values]

data_uniqueness = {(i[0], i[1]): same_hp for i, same_hp in zip(data_uniqueness.index.values, data_uniqueness["HP Match"].values)}

data["HP Match"] = [data_uniqueness[b_ae, pc] for b_ae, pc in data[["Primary AE Model", "Processed Classifier"]].values]
data["Classifier"] = data["Processed Classifier"]
data = data.drop(columns=["Processed Classifier"])

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier", "Attempt", "HP Match", "precision", "recall", "f-score", "auc"]]

data.head()
# Out:
#   Dataset            Type Input Size Primary AE Model  \
# 0  Task 3  Adversarial AE       4096   20230224233553
# 1  Task 3  Adversarial AE       4096   20230224233553
# 2  Task 3  Adversarial AE       4096   20230224233553
# 3  Task 3  Adversarial AE       4096   20230224233553
# 4  Task 3  Adversarial AE       4096   20230224233553
#
#                      Classifier Attempt  HP Match  precision    recall  \
# 0  ReconstructionThreshold_1.05       0      True   0.139535  0.222222
# 1   ReconstructionThreshold_1.1       0      True   0.139535  0.222222
# 2   ReconstructionThreshold_1.5       0      True   0.166667  0.185185
# 3   ReconstructionThreshold_3.0       0      True   0.000000  0.000000
# 4   ReconstructionThreshold_4.5       0      True   0.000000  0.000000
#
#     f-score  auc
# 0  0.171429  NaN
# 1  0.171429  NaN
# 2  0.175439  NaN
# 3  0.000000  NaN
# 4  0.000000  NaN

# %%
# Rename p, r and f1
data = data.rename(columns={"precision": "Precision", "recall": "Recall", "f-score": "F1-Score", "auc": "Area Under Curve"})

# %%
# Create final table
def row_max(df):
    max_f1 = df["F1-Score"].max()
    for r, f1 in zip(df.values, df["F1-Score"].values):
        if f1 == max_f1:
            return pd.DataFrame([r], columns=["Precision", "Recall", "F1-Score", "Area Under Curve", "Precision Standard Deviation", "Recall Standard Deviation", "F1-Score Standard Deviation", "Area Under Curve Standard Deviation"])
    

if ALLOW_ONLY_HP_MATCHES:
    data = data[data["HP Match"]]

data = data[["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier", "Precision", "Recall", "F1-Score", "Area Under Curve"]]
data_std = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"]).std()
data = data.groupby(["Dataset", "Type", "Input Size", "Primary AE Model", "Classifier"]).mean()

data[["Precision Standard Deviation", "Recall Standard Deviation", "F1-Score Standard Deviation", "Area Under Curve Standard Deviation"]] = data_std[["Precision", "Recall", "F1-Score", "Area Under Curve"]]


data = data.groupby(["Dataset", "Input Size", "Type", "Classifier"]).apply(row_max)

formated_strings = ["%.4f (%.4f, %.4f)" % (f, p, r) for p, r, f in data[["Precision", "Recall", "F1-Score"]].values]
data["Formated Results"] = formated_strings

data = data.sort_values(["Type", "F1-Score"], ascending=False)

data.head()
# Out:
#                                                               Precision  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0   0.916667
#                               ReconstructionThreshold_1.1  0   0.916667
#                               ReconstructionThreshold_1.5  0   0.916667
#         4096       Vanilla AE GradientBoostingClassifier   0   0.843333
#         12288      Vanilla AE KNeighborsClassifier         0   0.666667
#
#                                                                 Recall  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0  0.814815
#                               ReconstructionThreshold_1.1  0  0.814815
#                               ReconstructionThreshold_1.5  0  0.814815
#         4096       Vanilla AE GradientBoostingClassifier   0  0.725476
#         12288      Vanilla AE KNeighborsClassifier         0  0.750000
#
#                                                               F1-Score  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0  0.862745
#                               ReconstructionThreshold_1.1  0  0.862745
#                               ReconstructionThreshold_1.5  0  0.862745
#         4096       Vanilla AE GradientBoostingClassifier   0  0.758095
#         12288      Vanilla AE KNeighborsClassifier         0  0.705882
#
#                                                               Area Under Curve  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0               NaN
#                               ReconstructionThreshold_1.1  0               NaN
#                               ReconstructionThreshold_1.5  0               NaN
#         4096       Vanilla AE GradientBoostingClassifier   0               NaN
#         12288      Vanilla AE KNeighborsClassifier         0               NaN
#
#                                                               Precision Standard Deviation  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0                           NaN
#                               ReconstructionThreshold_1.1  0                           NaN
#                               ReconstructionThreshold_1.5  0                           NaN
#         4096       Vanilla AE GradientBoostingClassifier   0                      0.150739
#         12288      Vanilla AE KNeighborsClassifier         0                           NaN
#
#                                                               Recall Standard Deviation  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0                        NaN
#                               ReconstructionThreshold_1.1  0                        NaN
#                               ReconstructionThreshold_1.5  0                        NaN
#         4096       Vanilla AE GradientBoostingClassifier   0                   0.273918
#         12288      Vanilla AE KNeighborsClassifier         0                        NaN
#
#                                                               F1-Score Standard Deviation  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0                          NaN
#                               ReconstructionThreshold_1.1  0                          NaN
#                               ReconstructionThreshold_1.5  0                          NaN
#         4096       Vanilla AE GradientBoostingClassifier   0                     0.207523
#         12288      Vanilla AE KNeighborsClassifier         0                          NaN
#
#                                                               Area Under Curve Standard Deviation  \
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0                                  NaN
#                               ReconstructionThreshold_1.1  0                                  NaN
#                               ReconstructionThreshold_1.5  0                                  NaN
#         4096       Vanilla AE GradientBoostingClassifier   0                                  NaN
#         12288      Vanilla AE KNeighborsClassifier         0                                  NaN
#
#                                                                      Formated Results
# Dataset Input Size Type       Classifier
# Task 3  12288      Vanilla AE ReconstructionThreshold_1.05 0  0.8627 (0.9167, 0.8148)
#                               ReconstructionThreshold_1.1  0  0.8627 (0.9167, 0.8148)
#                               ReconstructionThreshold_1.5  0  0.8627 (0.9167, 0.8148)
#         4096       Vanilla AE GradientBoostingClassifier   0  0.7581 (0.8433, 0.7255)
#         12288      Vanilla AE KNeighborsClassifier         0  0.7059 (0.6667, 0.7500)

# %%
# Save final table

data.to_csv("Final LL Classifiers Table.csv")
