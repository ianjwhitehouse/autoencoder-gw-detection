# %%
# Load data
import pandas as pd

data = pd.read_csv("ae_trials.csv")
data.head()
# Out:
#              name dataset            type  attempt        leader  input_size  \
# 0  20230224233553  Task 3  Adversarial AE        0           NaN        4096
# 1  20230224234106  Task 3      Vanilla AE        0  2.023022e+13        4096
# 2  20230224234323  Task 3  Adversarial AE        1  2.023022e+13        4096
# 3  20230224234831  Task 3      Vanilla AE        1  2.023022e+13        4096
# 4  20230224235042  Task 3  Adversarial AE        2  2.023022e+13        4096
#
#    hidden_layers  hidden_layers_divisor  z_layer_divisor  dropout  \
# 0              2                      2                4      0.5
# 1              2                      2                4      0.5
# 2              2                      2                4      0.5
# 3              2                      2                4      0.5
# 4              2                      2                4      0.5
#
#    learning_rate  batch_size  gen_loss  disc_loss  val_loss  epochs
# ...

# %%
data["len"] = [1 for d in data.values]

data.to_csv("ae_trials.csv")
